# %%
import os
from tkinter import Tk, Label, Button, PhotoImage
from PIL import Image, ImageTk
import shutil

source_folder = 'scratch'

# Paths

target_folder_a = 'broken_part'
target_folder_b = 'broken_part_scratch'
target_folder_c = 'broken_part_scratch_wind_screen'
target_folder_d = 'broken_part_scratch_wind_screen_dent'
target_folder_e = 'broken_part_scratch_dent'
target_folder_f = 'broken_part_wind_screen'
target_folder_g = 'broken_part_wind_screen_dent'
target_folder_h = 'broken_part_dent'

target_folder_i = 'scratch'
target_folder_j = 'scratch_wind_screen'
target_folder_k = 'scratch_wind_screen_dent'
target_folder_l = 'scratch_dent'

target_folder_m = 'wind_screen'
target_folder_n = 'wind_screen_dent'

target_folder_o = 'dent'

target_folder_p = 'misc'



def copy_to_folder_a():
    path_track.append(target_folder_a)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_a:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_a)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_a)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))
def copy_to_folder_b():
    path_track.append(target_folder_b)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_b:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_b)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_b)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))


def copy_to_folder_c():
    path_track.append(target_folder_c)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_c:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_c)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_c)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_d():
    path_track.append(target_folder_d)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_d:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_d)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_d)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_e():
    path_track.append(target_folder_e)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_e:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_e)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_e)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_f():
    path_track.append(target_folder_f)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_f:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_f)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_f)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_g():
    path_track.append(target_folder_g)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_g:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_g)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_g)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_h():
    path_track.append(target_folder_h)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_h:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_h)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_h)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_i():
    path_track.append(target_folder_i)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_i:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_i)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_i)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_j():
    path_track.append(target_folder_j)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_j:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_j)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_j)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))


def copy_to_folder_k():
    path_track.append(target_folder_k)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_k:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_k)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_k)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))



def copy_to_folder_l():
    path_track.append(target_folder_l)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_l:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_l)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_l)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))



def copy_to_folder_m():
    path_track.append(target_folder_m)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_m:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_m)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_m)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))



def copy_to_folder_n():
    path_track.append(target_folder_n)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_n:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_n)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_n)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

def copy_to_folder_o():
    path_track.append(target_folder_o)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_o:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_o)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_o)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))


def copy_to_folder_p():
    path_track.append(target_folder_p)
    global current_image_index
    if current_image_index < len(images):
        if source_folder!=target_folder_p:
            shutil.move(os.path.join('test/'+source_folder, images[current_image_index]), 'test/'+target_folder_p)
            shutil.move(os.path.join('ground_truth/'+source_folder, ground_truth_images[current_image_index]), 'ground_truth/'+target_folder_p)
        current_image_index += 1
        if current_image_index < len(images):
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))



os.makedirs('test/'+target_folder_a, exist_ok=True)
os.makedirs('test/'+target_folder_b, exist_ok=True)
os.makedirs('test/'+target_folder_c, exist_ok=True)
os.makedirs('test/'+target_folder_d, exist_ok=True)
os.makedirs('test/'+target_folder_e, exist_ok=True)
os.makedirs('test/'+target_folder_f, exist_ok=True)
os.makedirs('test/'+target_folder_g, exist_ok=True)
os.makedirs('test/'+target_folder_h, exist_ok=True)
os.makedirs('test/'+target_folder_i, exist_ok=True)
os.makedirs('test/'+target_folder_j, exist_ok=True)
os.makedirs('test/'+target_folder_k, exist_ok=True)
os.makedirs('test/'+target_folder_l, exist_ok=True)
os.makedirs('test/'+target_folder_m, exist_ok=True)
os.makedirs('test/'+target_folder_n, exist_ok=True)
os.makedirs('test/'+target_folder_o, exist_ok=True)
os.makedirs('test/'+target_folder_p, exist_ok=True)

os.makedirs('ground_truth/'+target_folder_a, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_b, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_c, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_d, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_e, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_f, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_g, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_h, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_i, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_j, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_k, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_l, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_m, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_n, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_o, exist_ok=True)
os.makedirs('ground_truth/'+target_folder_p, exist_ok=True)

path_track = []

# List of images
images = [img for img in os.listdir('test/'+source_folder) if img.endswith('.png')]
images.sort()
ground_truth_images = [img for img in os.listdir('ground_truth/'+source_folder) if img.endswith('.png')]
ground_truth_images.sort()
current_image_index = 0
def update_image_label(image_path):
    print(current_image_index, '/', len(images))
    global photo  # Keep a reference to avoid garbage-collection
    img = Image.open(image_path)
    img.thumbnail((800, 600))  # Optional: Resize image to fit your screen
    photo = ImageTk.PhotoImage(img)
    image_label.config(image=photo)
    image_label.photo = photo  # Keep a reference


def redo_last():
    global current_image_index
    if current_image_index > 0:
            current_image_index -= 1
            if source_folder!=path_track[current_image_index]:
                shutil.move(os.path.join('test/', path_track[current_image_index], images[current_image_index]), os.path.join('test/', source_folder))
                shutil.move(os.path.join('ground_truth/', path_track[current_image_index], ground_truth_images[current_image_index]), os.path.join('ground_truth/', source_folder))
            update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))

            path_track.pop()







# Set up the GUI
root = Tk()
root.title("Image Copier")
image_label = Label(root)
image_label.pack()

button_a = Button(root, text="bp", command=copy_to_folder_a)
button_a.pack(side='left', padx=(20, 10), pady=20)
button_b = Button(root, text="bp_s", command=copy_to_folder_b)
button_b.pack(side='left', padx=(20, 10), pady=20)
button_c = Button(root, text="bp_s_ws", command=copy_to_folder_c)
button_c.pack(side='left', padx=(20, 10), pady=20)
button_d = Button(root, text="bp_s_ws_d", command=copy_to_folder_d)
button_d.pack(side='left', padx=(20, 10), pady=20)
button_e = Button(root, text="bp_s_d", command=copy_to_folder_e)
button_e.pack(side='left', padx=(20, 10), pady=20)
button_f = Button(root, text="bp_ws", command=copy_to_folder_f)
button_f.pack(side='left', padx=(20, 10), pady=20)
button_g = Button(root, text="bp_ws_d", command=copy_to_folder_g)
button_g.pack(side='left', padx=(20, 10), pady=20)
button_h = Button(root, text="bp_dp", command=copy_to_folder_h)
button_h.pack(side='left', padx=(10, 20), pady=20)

button_i = Button(root, text="s", command=copy_to_folder_i)
button_i.pack(side='right', padx=(10, 20), pady=20)
button_j = Button(root, text="s_ws", command=copy_to_folder_j)
button_j.pack(side='right', padx=(10, 20), pady=20)
button_k = Button(root, text="s_ws_d", command=copy_to_folder_k)
button_k.pack(side='right', padx=(10, 20), pady=20)
button_l = Button(root, text="s_d", command=copy_to_folder_l)
button_l.pack(side='right', padx=(20, 10), pady=20)

button_m = Button(root, text="ws", command=copy_to_folder_m)
button_m.pack(side='top', padx=(20, 10), pady=20)
button_n = Button(root, text="ws_d", command=copy_to_folder_n)
button_n.pack(side='top', padx=(20, 10), pady=20)

button_o = Button(root, text="dent", command=copy_to_folder_o)
button_o.pack(side='bottom', padx=(10, 20), pady=20)

button_p = Button(root, text="misc", command=copy_to_folder_p)
button_p.pack(side='bottom', padx=(10, 20), pady=20)


button_redo_last = Button(root, text="Redo", command=redo_last)
button_redo_last.pack(side='bottom', padx=(10, 20), pady=20)
# Display the first image
if images:
    update_image_label(os.path.join('test/'+source_folder, images[current_image_index]))
else:
    print("No images found in the 'damage' folder.")
root.mainloop()
# Out:
# 0 / 520
